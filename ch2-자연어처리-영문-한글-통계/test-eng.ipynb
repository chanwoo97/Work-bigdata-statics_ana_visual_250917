# %% [markdown]
# # 영문 분석 -> 워드 클라우드로 그리기(시각화)
#
# ## 샘플 데이터 영문 학술 문서의 제목만 추출, 그 단어의 빈도 분석 시각화
# ## 데이터 수집 : Big data 키워드로 검색 후, 해당 학술 연구 정보 서비스에서 수집 해보기.
# ## 조합, pandas.concat(), 정제 re 정규식, 기본적인 유효성 체크.
# ## 변환 : word_tokenize(), lower(),
# ## matplotlib.pyplot 이용하기.
# ## 단어 빈도 구해주는 Counter() 이용.
#
# ## 비정형 빅데이터 분석을 말하고 -> 자연어 처리 (nature language processing )
# ## 자연어 처리 예) 음성, 텍스트 정보 추출.
#
# ## 단어 빈도를 추출해서, 해당 단어 시각화하기.

# %% [markdown]
# # 관련 단어 용어 정리
# ## 텍스트 분석: 자연어 처리와 데이터 마이닝 결합하여 발전되었고,
# ## 비정형 텍스트 데이터에서 정보를 추출하는 분석 방법.
# ## 분석 방법 : 1) 텍스트 분류 2) 텍스트 군집화 3) 감성 분석.
#
# ## 전처리 : 분석 작업의 정확도를 높이기 위해서 사용할 데이터 정리하고 변환하는 작업.
# ### 수행하는 작업
# ### 정제 (cleaning): 불필요한 기호, 문자 필터하는 작업, 정규식을 이용해서 작업을 함.
# ### 정규화 ( normallization) : 형태가 다른 단어를 특정의 형태로 변환 작업 , 대문자, 소문자 통합 하는 작업, 의미가 비슷한 단어끼리 통합작업.
# ### 토큰화 (tokenization) : 토큰으로 정하는 기본 단위로 분리 작업. 문장 기준, 단어 기준이 될수 도 있다.
# ### 불용어제거(stopword) : 의미 있는 단어를 추출하기 위해서, 조사, 관사, 접미사, 접두사 등. 제거하는 작업.
# ### 어간 추출(semming) : 단수, 복수, 진행형(시제), 분리하는 작업
# ### 표제어 추출(lemmatization ): 단어의 기본형 형태로 일반화 하는 작업.
# ### 예)
# ### Gone -> go
# ### am -> be
# ### going -> go
#
# ## 워드클라우드 : 텍스트 분석에서 빈도를 시각화 할 때 많이 사용됨.

# %% [markdown]
# # 데이터 수집
# # 한국교육학술정보원 (KERIS)의 RISS 사이트
# # https://www.riss.kr/index.do
# # Big data 검색해보기.
# # 한 페이지당 100개씩 내보내기 엑셀 파일 간략 정보 , 반복 10번
# # 1000개의 데이터에서 제목만 추출 및 분류 작업하기.

# %% [markdown]
# # 데이터 준비 작업.
# # 제목 컬럼 빈도 분석 해보기.

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# 관련 패키지들 임포트 하기. 
import pandas as pd 
# 경로 이름 지정해서 파일 처리할 때 사용하는 도구
import glob 
# 정규 표현식에 사용하는 도구 
import re 
# 2차원 리스트를 -> 1차원 리스트로 차원 축소시 사용하는 도구 
from functools import reduce
# 자연어 처리 패키지 중에서, 단어 토큰화 작업.
from nltk.tokenize import word_tokenize
# 불용어 처리 작업. 
from nltk.corpus import stopwords 
# 표제어 추출 
from nltk.stem import WordNetLemmatizer 
# 단어의 빈도를 추출하는 도구. 
from collections import Counter 
import matplotlib.pyplot as plt
# 단어의 빈도수를 시각화하는 도구, 빈도가 높을수록 글자 크기가 커짐. 
from wordcloud import STOPWORDS, WordCloud

# %%
# 데이터 조합(병합)하기. 
# 현재 폴더 내부에 있는 , 받았던 엑셀 파일명 10개를 선택하기. 
# all_files = glob.glob("./myCabinetExcelData*.xls")
all_files = glob.glob("./exportExcelData_*.xls")
all_files

# 엑셀 파일 읽어서 -> 데이터 프레임 (표형태) 변환 ->특정 리스트에 담아두기 
# 임시로 저장할 리스트 변수 
all_files_data = []

# all_files 에 담겨진 엑셀 파일의 위치가 들어있고, 
# 해당 위치의 엑셀 파일을 읽어서, 데이터 프레임 표 형태로 변환하기. 
# 임시 리스트에 담기. 
for file in all_files:
  # 해당 엑셀 파일의 위치의 물리 파일 읽기
  data_frame = pd.read_excel(file)
  # 임시 리스트에 담기. 
  all_files_data.append(data_frame)

# 샘플 확인 해보기., 첫번째 요소 확인 해보기. 
# all_files_data = [엑셀1,엑셀2,엑셀3,...엑셀10]
all_files_data[0]

# 오류 발생, 모듈 미설치 : xlrd
# cmd -> pip install xlrd
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1        Architecting Time-Critical Big-Data Systems
# 1          NaN    2  <bold>D</bold>ense <bold>o</bold>r <bold>S</bo...
# 2          NaN    3  A Game Theoretic Approach for Addressing Domai...
# 3          NaN    4  A trust-based crowdfunding campaign marketing ...
# 4          NaN    5  Computation migration: a new approach to execu...
# ..         ...  ...                                                ...
# 95         NaN   96  Big data analysis of swimming pools' impact on...
# 96         NaN   97  An Ensemble-Based Scalable Approach for Intrus...
# 97         NaN   98  Sharing Medical Big Data While Preserving Pati...
# 98         NaN   99  Learning from Failure: Big Data Analysis for D...
# 99         NaN  100       A Bibliometric Review of Big Data in Finance
#
#                                                    저자               출판사   출판일
# 0   Basanta-Val, P.; Audsley, N. C.; Wellings, A. ...           unknown  2016
# 1                                          Choi, Unho           unknown  2022
# 2                                  Raghavan, Krishnan           unknown  2022
# 3                  Baah-Peprah, Prince; Shneor, Rotem      Inderscience  2021
# 4          Nunes, Rickey T. P.; Deshpande, Santosh L.      Inderscience  2018
# ..                                                ...               ...   ...
# 95  Elnakat, Afamia; Gomez, Juan D.; Roberts, Jaso...      Inderscience  2015
# 96  Sahu, Santosh Kumar; Mohapatra, Durga Prasad; ...  Mary Ann Leibert  2021
# 97  SCHRöDER, M.;MULLER, S. H. A.;VRADI, E.;MIELKE...  Mary Ann Liebert  2023
# 98                       CAVICCHIOLI, M.KOCOLLARI, U.  Mary Ann Liebert  2021
# 99                                        NOBANEE, H.  Mary Ann Liebert  2021
#
# [100 rows x 6 columns]

# %%
# 엑셀 파일 10개를 병합해서 출력해보기. 
# axis=0 , 세로 방향으로 , 밑으로 데이터를 붙이는 작업. 
all_files_data_concat = pd.concat(all_files_data, axis=0, ignore_index=True)
print(f"all_files_data_concat.shape : {all_files_data_concat.shape}")

# 병합된 파일을 csv 파일로 변환하기. 
all_files_data_concat.to_csv("./riss_Bigdata_2025.csv", encoding="utf-8", index=False)
# Out:
# all_files_data_concat.shape : (1000, 6)

# %%
# 전처리 작업 하기. 
# 데이터 프레임에서 제목 열만 추출 
all_title = all_files_data_concat["제목"]
all_title

#불용어 제거 
# set(), 기본적으로 중복 제거

# NLTK(Natural Language Toolkit) 라이브러리의 stopwords 모듈에서
# 영어에 해당하는 불용어 리스트를 가져옵니다.
# 불용어는 "the", "is", "in" 등처럼 분석에 크게 기여하지 않는, 자주 등장하는 단어들을 의미합니다.
stopWords = set(stopwords.words("english"))

# lemma 작업 -> 표제어 추출, 영어, 시제를 제거하고, 원형(사전식 단어 추출)
lemma = WordNetLemmatizer()

# %%
# 임시로 담을 변수, 
words = []

# 기본적인 , 단어 추출(전처리 작업.)
for title in all_title:
  # 영문자, 대 소문자를 제외한 나머지 문자는 모두 공백으로 처리하겠다. 
  print(f"과정1 title 원본: {title}")
  enWords = re.sub(r"[^a-zA-Z]+"," ",str(title))
  print(f"과정2 title enWords(re: 대소문자남기기): {enWords}")
  # 남은 영문자를 -> 모두 소문자 변환하고 -> 각단어를 토큰으로 각각 분리 작업. 
  enWordsToken = word_tokenize(enWords.lower())
  print(f"과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): {enWordsToken}")
  # 컴프리헨션 파이썬 스타일 코드로 , 리스로 변경하기. 
  
  # 불용어 제거 작업, 조사, 관사 등 제거하는 작업. -> 오타:stopwords -> stopWords
  enWordsTokenStop= [w for w in enWordsToken if w not in stopWords]
  print(f"과정4 title enWordsTokenStop(불용어 제거): {enWordsTokenStop}")

  # 표제어 추출 작업. 
  enWordsTokenStopLemma = [lemma.lemmatize(w) for w in enWordsTokenStop]
  print(f"과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): {enWordsTokenStopLemma}")

  words.append(enWordsTokenStopLemma)
  
print(f"words(전처리, re 정규식, token화, stop 불용어 제거, 표제어 추출) : {words}")
# Out:
# 과정1 title 원본: Architecting Time-Critical Big-Data Systems
# 과정2 title enWords(re: 대소문자남기기): Architecting Time Critical Big Data Systems
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['architecting', 'time', 'critical', 'big', 'data', 'systems']
# 과정4 title enWordsTokenStop(불용어 제거): ['architecting', 'time', 'critical', 'big', 'data', 'systems']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['architecting', 'time', 'critical', 'big', 'data', 'system']
# 과정1 title 원본: <bold>D</bold>ense <bold>o</bold>r <bold>S</bold>parse : Elastic SPMM Implementation for Optimal Big-Data Processing
# 과정2 title enWords(re: 대소문자남기기):  bold D bold ense bold o bold r bold S bold parse Elastic SPMM Implementation for Optimal Big Data Processing
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['bold', 'd', 'bold', 'ense', 'bold', 'o', 'bold', 'r', 'bold', 's', 'bold', 'parse', 'elastic', 'spmm', 'implementation', 'for', 'optimal', 'big', 'data', 'processing']
# 과정4 title enWordsTokenStop(불용어 제거): ['bold', 'bold', 'ense', 'bold', 'bold', 'r', 'bold', 'bold', 'parse', 'elastic', 'spmm', 'implementation', 'optimal', 'big', 'data', 'processing']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['bold', 'bold', 'ense', 'bold', 'bold', 'r', 'bold', 'bold', 'parse', 'elastic', 'spmm', 'implementation', 'optimal', 'big', 'data', 'processing']
# 과정1 title 원본: A Game Theoretic Approach for Addressing Domain-Shift in Big-Data
# 과정2 title enWords(re: 대소문자남기기): A Game Theoretic Approach for Addressing Domain Shift in Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'game', 'theoretic', 'approach', 'for', 'addressing', 'domain', 'shift', 'in', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['game', 'theoretic', 'approach', 'addressing', 'domain', 'shift', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['game', 'theoretic', 'approach', 'addressing', 'domain', 'shift', 'big', 'data']
# 과정1 title 원본: A trust-based crowdfunding campaign marketing framework: theoretical underpinnings and big-data analytics practice
# 과정2 title enWords(re: 대소문자남기기): A trust based crowdfunding campaign marketing framework theoretical underpinnings and big data analytics practice
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'trust', 'based', 'crowdfunding', 'campaign', 'marketing', 'framework', 'theoretical', 'underpinnings', 'and', 'big', 'data', 'analytics', 'practice']
# 과정4 title enWordsTokenStop(불용어 제거): ['trust', 'based', 'crowdfunding', 'campaign', 'marketing', 'framework', 'theoretical', 'underpinnings', 'big', 'data', 'analytics', 'practice']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['trust', 'based', 'crowdfunding', 'campaign', 'marketing', 'framework', 'theoretical', 'underpinnings', 'big', 'data', 'analytics', 'practice']
# 과정1 title 원본: Computation migration: a new approach to execute big-data bioinformatics workflows
# 과정2 title enWords(re: 대소문자남기기): Computation migration a new approach to execute big data bioinformatics workflows
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['computation', 'migration', 'a', 'new', 'approach', 'to', 'execute', 'big', 'data', 'bioinformatics', 'workflows']
# 과정4 title enWordsTokenStop(불용어 제거): ['computation', 'migration', 'new', 'approach', 'execute', 'big', 'data', 'bioinformatics', 'workflows']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['computation', 'migration', 'new', 'approach', 'execute', 'big', 'data', 'bioinformatics', 'workflow']
# 과정1 title 원본: Big Data, Small Personas: How Algorithms Shape the Demographic Representation of Data-Driven User Segments
# 과정2 title enWords(re: 대소문자남기기): Big Data Small Personas How Algorithms Shape the Demographic Representation of Data Driven User Segments
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'small', 'personas', 'how', 'algorithms', 'shape', 'the', 'demographic', 'representation', 'of', 'data', 'driven', 'user', 'segments']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'small', 'personas', 'algorithms', 'shape', 'demographic', 'representation', 'data', 'driven', 'user', 'segments']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'small', 'persona', 'algorithm', 'shape', 'demographic', 'representation', 'data', 'driven', 'user', 'segment']
# 과정1 title 원본: Big Scholarly Data: A Survey
# 과정2 title enWords(re: 대소문자남기기): Big Scholarly Data A Survey
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'scholarly', 'data', 'a', 'survey']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'scholarly', 'data', 'survey']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'scholarly', 'data', 'survey']
# 과정1 title 원본: Data-Efficient Performance Modeling for Configurable Big Data Frameworks by Reducing Information Overlap Between Training Examples
# 과정2 title enWords(re: 대소문자남기기): Data Efficient Performance Modeling for Configurable Big Data Frameworks by Reducing Information Overlap Between Training Examples
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['data', 'efficient', 'performance', 'modeling', 'for', 'configurable', 'big', 'data', 'frameworks', 'by', 'reducing', 'information', 'overlap', 'between', 'training', 'examples']
# 과정4 title enWordsTokenStop(불용어 제거): ['data', 'efficient', 'performance', 'modeling', 'configurable', 'big', 'data', 'frameworks', 'reducing', 'information', 'overlap', 'training', 'examples']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['data', 'efficient', 'performance', 'modeling', 'configurable', 'big', 'data', 'framework', 'reducing', 'information', 'overlap', 'training', 'example']
# 과정1 title 원본: Comment on “A Revolution That Will Transform How We Live, Work, and Think: An Interview with the Authors of Big Data”
# 과정2 title enWords(re: 대소문자남기기): Comment on A Revolution That Will Transform How We Live Work and Think An Interview with the Authors of Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['comment', 'on', 'a', 'revolution', 'that', 'will', 'transform', 'how', 'we', 'live', 'work', 'and', 'think', 'an', 'interview', 'with', 'the', 'authors', 'of', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['comment', 'revolution', 'transform', 'live', 'work', 'think', 'interview', 'authors', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['comment', 'revolution', 'transform', 'live', 'work', 'think', 'interview', 'author', 'big', 'data']
# 과정1 title 원본: Predictive Modeling With Big Data: Is Bigger Really Better?
# 과정2 title enWords(re: 대소문자남기기): Predictive Modeling With Big Data Is Bigger Really Better
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['predictive', 'modeling', 'with', 'big', 'data', 'is', 'bigger', 'really', 'better']
# 과정4 title enWordsTokenStop(불용어 제거): ['predictive', 'modeling', 'big', 'data', 'bigger', 'really', 'better']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['predictive', 'modeling', 'big', 'data', 'bigger', 'really', 'better']
# 과정1 title 원본: Scientific Training in the Era of Big Data: A New Pedagogy for Graduate Education
# 과정2 title enWords(re: 대소문자남기기): Scientific Training in the Era of Big Data A New Pedagogy for Graduate Education
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['scientific', 'training', 'in', 'the', 'era', 'of', 'big', 'data', 'a', 'new', 'pedagogy', 'for', 'graduate', 'education']
# 과정4 title enWordsTokenStop(불용어 제거): ['scientific', 'training', 'era', 'big', 'data', 'new', 'pedagogy', 'graduate', 'education']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['scientific', 'training', 'era', 'big', 'data', 'new', 'pedagogy', 'graduate', 'education']
# 과정1 title 원본: Call for Special Issue Papers: Big Data-Driven Futuristic Fabric System in Societal Digital Transformation
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data Driven Futuristic Fabric System in Societal Digital Transformation
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'in', 'societal', 'digital', 'transformation']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation']
# 과정1 title 원본: Call for Special Issue Papers: Big Data-Driven Futuristic Fabric System in Societal Digital Transformation
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data Driven Futuristic Fabric System in Societal Digital Transformation
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'in', 'societal', 'digital', 'transformation']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation']
# 과정1 title 원본: Scalable Data Quality for Big Data: The Pythia Framework for Handling Missing Values
# 과정2 title enWords(re: 대소문자남기기): Scalable Data Quality for Big Data The Pythia Framework for Handling Missing Values
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['scalable', 'data', 'quality', 'for', 'big', 'data', 'the', 'pythia', 'framework', 'for', 'handling', 'missing', 'values']
# 과정4 title enWordsTokenStop(불용어 제거): ['scalable', 'data', 'quality', 'big', 'data', 'pythia', 'framework', 'handling', 'missing', 'values']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['scalable', 'data', 'quality', 'big', 'data', 'pythia', 'framework', 'handling', 'missing', 'value']
# 과정1 title 원본: Authors' Response to Gong's, “Comment on Data Science and its Relationship to Big Data and Data-Driven Decision Making”
# 과정2 title enWords(re: 대소문자남기기): Authors Response to Gong s Comment on Data Science and its Relationship to Big Data and Data Driven Decision Making
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['authors', 'response', 'to', 'gong', 's', 'comment', 'on', 'data', 'science', 'and', 'its', 'relationship', 'to', 'big', 'data', 'and', 'data', 'driven', 'decision', 'making']
# 과정4 title enWordsTokenStop(불용어 제거): ['authors', 'response', 'gong', 'comment', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['author', 'response', 'gong', 'comment', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making']
# 과정1 title 원본: Call for Special Issue Papers: Big Data-Driven Futuristic Fabric System in Societal Digital Transformation
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data Driven Futuristic Fabric System in Societal Digital Transformation
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'in', 'societal', 'digital', 'transformation']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation']
# 과정1 title 원본: Bring it on, Big Data: Beyond the Hype
# 과정2 title enWords(re: 대소문자남기기): Bring it on Big Data Beyond the Hype
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['bring', 'it', 'on', 'big', 'data', 'beyond', 'the', 'hype']
# 과정4 title enWordsTokenStop(불용어 제거): ['bring', 'big', 'data', 'beyond', 'hype']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['bring', 'big', 'data', 'beyond', 'hype']
# 과정1 title 원본: Correction to: Predictive Modeling with Big Data: Is Bigger Really Better? by Junqué de Fortuny E, Martens D, and Provost F. Big Data 2013;1(4):215–226.
# 과정2 title enWords(re: 대소문자남기기): Correction to Predictive Modeling with Big Data Is Bigger Really Better by Junqu de Fortuny E Martens D and Provost F Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['correction', 'to', 'predictive', 'modeling', 'with', 'big', 'data', 'is', 'bigger', 'really', 'better', 'by', 'junqu', 'de', 'fortuny', 'e', 'martens', 'd', 'and', 'provost', 'f', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['correction', 'predictive', 'modeling', 'big', 'data', 'bigger', 'really', 'better', 'junqu', 'de', 'fortuny', 'e', 'martens', 'provost', 'f', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['correction', 'predictive', 'modeling', 'big', 'data', 'bigger', 'really', 'better', 'junqu', 'de', 'fortuny', 'e', 'marten', 'provost', 'f', 'big', 'data']
# 과정1 title 원본: Sports Analytics in the Era of Big Data: Moving Toward the Next Frontier
# 과정2 title enWords(re: 대소문자남기기): Sports Analytics in the Era of Big Data Moving Toward the Next Frontier
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['sports', 'analytics', 'in', 'the', 'era', 'of', 'big', 'data', 'moving', 'toward', 'the', 'next', 'frontier']
# 과정4 title enWordsTokenStop(불용어 제거): ['sports', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['sport', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier']
# 과정1 title 원본: Sports Analytics in the Era of Big Data: Moving Toward the Next Frontier
# 과정2 title enWords(re: 대소문자남기기): Sports Analytics in the Era of Big Data Moving Toward the Next Frontier
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['sports', 'analytics', 'in', 'the', 'era', 'of', 'big', 'data', 'moving', 'toward', 'the', 'next', 'frontier']
# 과정4 title enWordsTokenStop(불용어 제거): ['sports', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['sport', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier']
# 과정1 title 원본: Comment on “Data Science and its Relationship to Big Data and Data-Driven Decision Making”
# 과정2 title enWords(re: 대소문자남기기): Comment on Data Science and its Relationship to Big Data and Data Driven Decision Making
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['comment', 'on', 'data', 'science', 'and', 'its', 'relationship', 'to', 'big', 'data', 'and', 'data', 'driven', 'decision', 'making']
# 과정4 title enWordsTokenStop(불용어 제거): ['comment', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['comment', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making']
# 과정1 title 원본: Multiple Targets Tracking with Big Data-Based Measurement for Extended Binary Phase Shift Keying Transceiver
# 과정2 title enWords(re: 대소문자남기기): Multiple Targets Tracking with Big Data Based Measurement for Extended Binary Phase Shift Keying Transceiver
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['multiple', 'targets', 'tracking', 'with', 'big', 'data', 'based', 'measurement', 'for', 'extended', 'binary', 'phase', 'shift', 'keying', 'transceiver']
# 과정4 title enWordsTokenStop(불용어 제거): ['multiple', 'targets', 'tracking', 'big', 'data', 'based', 'measurement', 'extended', 'binary', 'phase', 'shift', 'keying', 'transceiver']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['multiple', 'target', 'tracking', 'big', 'data', 'based', 'measurement', 'extended', 'binary', 'phase', 'shift', 'keying', 'transceiver']
# 과정1 title 원본: Big Data-Driven Futuristic Fabric System in Societal Digital Transformation
# 과정2 title enWords(re: 대소문자남기기): Big Data Driven Futuristic Fabric System in Societal Digital Transformation
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'in', 'societal', 'digital', 'transformation']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation']
# 과정1 title 원본: Big data: new methods and ideas in geological scientific research
# 과정2 title enWords(re: 대소문자남기기): Big data new methods and ideas in geological scientific research
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'new', 'methods', 'and', 'ideas', 'in', 'geological', 'scientific', 'research']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'new', 'methods', 'ideas', 'geological', 'scientific', 'research']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'new', 'method', 'idea', 'geological', 'scientific', 'research']
# 과정1 title 원본: The Role of Teamwork in the Analysis of Big Data: A Study of Visual Analytics and Box Office Prediction
# 과정2 title enWords(re: 대소문자남기기): The Role of Teamwork in the Analysis of Big Data A Study of Visual Analytics and Box Office Prediction
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'role', 'of', 'teamwork', 'in', 'the', 'analysis', 'of', 'big', 'data', 'a', 'study', 'of', 'visual', 'analytics', 'and', 'box', 'office', 'prediction']
# 과정4 title enWordsTokenStop(불용어 제거): ['role', 'teamwork', 'analysis', 'big', 'data', 'study', 'visual', 'analytics', 'box', 'office', 'prediction']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['role', 'teamwork', 'analysis', 'big', 'data', 'study', 'visual', 'analytics', 'box', 'office', 'prediction']
# 과정1 title 원본: Global water cycle and remote sensing big data: overview, challenge, and opportunities
# 과정2 title enWords(re: 대소문자남기기): Global water cycle and remote sensing big data overview challenge and opportunities
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['global', 'water', 'cycle', 'and', 'remote', 'sensing', 'big', 'data', 'overview', 'challenge', 'and', 'opportunities']
# 과정4 title enWordsTokenStop(불용어 제거): ['global', 'water', 'cycle', 'remote', 'sensing', 'big', 'data', 'overview', 'challenge', 'opportunities']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['global', 'water', 'cycle', 'remote', 'sensing', 'big', 'data', 'overview', 'challenge', 'opportunity']
# 과정1 title 원본: Deep learning for processing and analysis of remote sensing big data: a technical review
# 과정2 title enWords(re: 대소문자남기기): Deep learning for processing and analysis of remote sensing big data a technical review
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['deep', 'learning', 'for', 'processing', 'and', 'analysis', 'of', 'remote', 'sensing', 'big', 'data', 'a', 'technical', 'review']
# 과정4 title enWordsTokenStop(불용어 제거): ['deep', 'learning', 'processing', 'analysis', 'remote', 'sensing', 'big', 'data', 'technical', 'review']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['deep', 'learning', 'processing', 'analysis', 'remote', 'sensing', 'big', 'data', 'technical', 'review']
# 과정1 title 원본: Data Science and its Relationship to Big Data and Data-Driven Decision Making
# 과정2 title enWords(re: 대소문자남기기): Data Science and its Relationship to Big Data and Data Driven Decision Making
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['data', 'science', 'and', 'its', 'relationship', 'to', 'big', 'data', 'and', 'data', 'driven', 'decision', 'making']
# 과정4 title enWordsTokenStop(불용어 제거): ['data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making']
# 과정1 title 원본: Call for Special Issue Papers: Big Data-Driven Futuristic Fabric System in Societal Digital Transformation
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data Driven Futuristic Fabric System in Societal Digital Transformation
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'in', 'societal', 'digital', 'transformation']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation']
# 과정1 title 원본: Computational Propaganda and Political Big Data: Moving Toward a More Critical Research Agenda
# 과정2 title enWords(re: 대소문자남기기): Computational Propaganda and Political Big Data Moving Toward a More Critical Research Agenda
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['computational', 'propaganda', 'and', 'political', 'big', 'data', 'moving', 'toward', 'a', 'more', 'critical', 'research', 'agenda']
# 과정4 title enWordsTokenStop(불용어 제거): ['computational', 'propaganda', 'political', 'big', 'data', 'moving', 'toward', 'critical', 'research', 'agenda']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['computational', 'propaganda', 'political', 'big', 'data', 'moving', 'toward', 'critical', 'research', 'agenda']
# 과정1 title 원본: The Structural Consequences of Big Data-Driven Education
# 과정2 title enWords(re: 대소문자남기기): The Structural Consequences of Big Data Driven Education
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'structural', 'consequences', 'of', 'big', 'data', 'driven', 'education']
# 과정4 title enWordsTokenStop(불용어 제거): ['structural', 'consequences', 'big', 'data', 'driven', 'education']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['structural', 'consequence', 'big', 'data', 'driven', 'education']
# 과정1 title 원본: Software architectures for big data: a systematic literature review
# 과정2 title enWords(re: 대소문자남기기): Software architectures for big data a systematic literature review
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['software', 'architectures', 'for', 'big', 'data', 'a', 'systematic', 'literature', 'review']
# 과정4 title enWordsTokenStop(불용어 제거): ['software', 'architectures', 'big', 'data', 'systematic', 'literature', 'review']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['software', 'architecture', 'big', 'data', 'systematic', 'literature', 'review']
# 과정1 title 원본: Diversity in Big Data: A Review
# 과정2 title enWords(re: 대소문자남기기): Diversity in Big Data A Review
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['diversity', 'in', 'big', 'data', 'a', 'review']
# 과정4 title enWordsTokenStop(불용어 제거): ['diversity', 'big', 'data', 'review']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['diversity', 'big', 'data', 'review']
# 과정1 title 원본: Big Data–Artificial Intelligence Fusion Technology in Education in the Context of the New Crown Epidemic
# 과정2 title enWords(re: 대소문자남기기): Big Data Artificial Intelligence Fusion Technology in Education in the Context of the New Crown Epidemic
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'artificial', 'intelligence', 'fusion', 'technology', 'in', 'education', 'in', 'the', 'context', 'of', 'the', 'new', 'crown', 'epidemic']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'artificial', 'intelligence', 'fusion', 'technology', 'education', 'context', 'new', 'crown', 'epidemic']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'artificial', 'intelligence', 'fusion', 'technology', 'education', 'context', 'new', 'crown', 'epidemic']
# 과정1 title 원본: Mapping essential urban land use categories (EULUC) using geospatial big data: Progress, challenges, and opportunities
# 과정2 title enWords(re: 대소문자남기기): Mapping essential urban land use categories EULUC using geospatial big data Progress challenges and opportunities
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['mapping', 'essential', 'urban', 'land', 'use', 'categories', 'euluc', 'using', 'geospatial', 'big', 'data', 'progress', 'challenges', 'and', 'opportunities']
# 과정4 title enWordsTokenStop(불용어 제거): ['mapping', 'essential', 'urban', 'land', 'use', 'categories', 'euluc', 'using', 'geospatial', 'big', 'data', 'progress', 'challenges', 'opportunities']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['mapping', 'essential', 'urban', 'land', 'use', 'category', 'euluc', 'using', 'geospatial', 'big', 'data', 'progress', 'challenge', 'opportunity']
# 과정1 title 원본: Capturing the value of biosurveillance "big data" through natural capital accounting
# 과정2 title enWords(re: 대소문자남기기): Capturing the value of biosurveillance big data through natural capital accounting
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['capturing', 'the', 'value', 'of', 'biosurveillance', 'big', 'data', 'through', 'natural', 'capital', 'accounting']
# 과정4 title enWordsTokenStop(불용어 제거): ['capturing', 'value', 'biosurveillance', 'big', 'data', 'natural', 'capital', 'accounting']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['capturing', 'value', 'biosurveillance', 'big', 'data', 'natural', 'capital', 'accounting']
# 과정1 title 원본: Big-BOE: Fusing Spanish Official Gazette with Big Data Technology
# 과정2 title enWords(re: 대소문자남기기): Big BOE Fusing Spanish Official Gazette with Big Data Technology
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'boe', 'fusing', 'spanish', 'official', 'gazette', 'with', 'big', 'data', 'technology']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'boe', 'fusing', 'spanish', 'official', 'gazette', 'big', 'data', 'technology']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'boe', 'fusing', 'spanish', 'official', 'gazette', 'big', 'data', 'technology']
# 과정1 title 원본: Diastema: data-driven stack for big data applications management and deployment
# 과정2 title enWords(re: 대소문자남기기): Diastema data driven stack for big data applications management and deployment
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['diastema', 'data', 'driven', 'stack', 'for', 'big', 'data', 'applications', 'management', 'and', 'deployment']
# 과정4 title enWordsTokenStop(불용어 제거): ['diastema', 'data', 'driven', 'stack', 'big', 'data', 'applications', 'management', 'deployment']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['diastema', 'data', 'driven', 'stack', 'big', 'data', 'application', 'management', 'deployment']
# 과정1 title 원본: A big data-based RF localisation method for unmanned search and rescue
# 과정2 title enWords(re: 대소문자남기기): A big data based RF localisation method for unmanned search and rescue
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'big', 'data', 'based', 'rf', 'localisation', 'method', 'for', 'unmanned', 'search', 'and', 'rescue']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'based', 'rf', 'localisation', 'method', 'unmanned', 'search', 'rescue']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'based', 'rf', 'localisation', 'method', 'unmanned', 'search', 'rescue']
# 과정1 title 원본: Guest Editorial: Big Media Data: Understanding, Search, and Mining
# 과정2 title enWords(re: 대소문자남기기): Guest Editorial Big Media Data Understanding Search and Mining
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['guest', 'editorial', 'big', 'media', 'data', 'understanding', 'search', 'and', 'mining']
# 과정4 title enWordsTokenStop(불용어 제거): ['guest', 'editorial', 'big', 'media', 'data', 'understanding', 'search', 'mining']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining']
# 과정1 title 원본: Guest Editorial: Big Media Data: Understanding, Search, and Mining
# 과정2 title enWords(re: 대소문자남기기): Guest Editorial Big Media Data Understanding Search and Mining
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['guest', 'editorial', 'big', 'media', 'data', 'understanding', 'search', 'and', 'mining']
# 과정4 title enWordsTokenStop(불용어 제거): ['guest', 'editorial', 'big', 'media', 'data', 'understanding', 'search', 'mining']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining']
# 과정1 title 원본: Guest Editorial: Big Media Data: Understanding, Search, and Mining (Part 2)
# 과정2 title enWords(re: 대소문자남기기): Guest Editorial Big Media Data Understanding Search and Mining Part
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['guest', 'editorial', 'big', 'media', 'data', 'understanding', 'search', 'and', 'mining', 'part']
# 과정4 title enWordsTokenStop(불용어 제거): ['guest', 'editorial', 'big', 'media', 'data', 'understanding', 'search', 'mining', 'part']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining', 'part']
# 과정1 title 원본: A survey on data‐efficient algorithms in big data era
# 과정2 title enWords(re: 대소문자남기기): A survey on data efficient algorithms in big data era
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'survey', 'on', 'data', 'efficient', 'algorithms', 'in', 'big', 'data', 'era']
# 과정4 title enWordsTokenStop(불용어 제거): ['survey', 'data', 'efficient', 'algorithms', 'big', 'data', 'era']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['survey', 'data', 'efficient', 'algorithm', 'big', 'data', 'era']
# 과정1 title 원본: CatBoost for big data: an interdisciplinary review
# 과정2 title enWords(re: 대소문자남기기): CatBoost for big data an interdisciplinary review
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['catboost', 'for', 'big', 'data', 'an', 'interdisciplinary', 'review']
# 과정4 title enWordsTokenStop(불용어 제거): ['catboost', 'big', 'data', 'interdisciplinary', 'review']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['catboost', 'big', 'data', 'interdisciplinary', 'review']
# 과정1 title 원본: Privacy models for big data: a survey
# 과정2 title enWords(re: 대소문자남기기): Privacy models for big data a survey
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['privacy', 'models', 'for', 'big', 'data', 'a', 'survey']
# 과정4 title enWordsTokenStop(불용어 제거): ['privacy', 'models', 'big', 'data', 'survey']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['privacy', 'model', 'big', 'data', 'survey']
# 과정1 title 원본: Special Issue on Biomedical Big Data: Understanding, Learning and Applications
# 과정2 title enWords(re: 대소문자남기기): Special Issue on Biomedical Big Data Understanding Learning and Applications
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['special', 'issue', 'on', 'biomedical', 'big', 'data', 'understanding', 'learning', 'and', 'applications']
# 과정4 title enWordsTokenStop(불용어 제거): ['special', 'issue', 'biomedical', 'big', 'data', 'understanding', 'learning', 'applications']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['special', 'issue', 'biomedical', 'big', 'data', 'understanding', 'learning', 'application']
# 과정1 title 원본: A new approach for accurate distributed cluster analysis for Big Data: competitive K-Means
# 과정2 title enWords(re: 대소문자남기기): A new approach for accurate distributed cluster analysis for Big Data competitive K Means
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'new', 'approach', 'for', 'accurate', 'distributed', 'cluster', 'analysis', 'for', 'big', 'data', 'competitive', 'k', 'means']
# 과정4 title enWordsTokenStop(불용어 제거): ['new', 'approach', 'accurate', 'distributed', 'cluster', 'analysis', 'big', 'data', 'competitive', 'k', 'means']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['new', 'approach', 'accurate', 'distributed', 'cluster', 'analysis', 'big', 'data', 'competitive', 'k', 'mean']
# 과정1 title 원본: Visual Analysis of Multidimensional Big Data: A Scalable Lightweight Bundling Method for Parallel Coordinates
# 과정2 title enWords(re: 대소문자남기기): Visual Analysis of Multidimensional Big Data A Scalable Lightweight Bundling Method for Parallel Coordinates
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['visual', 'analysis', 'of', 'multidimensional', 'big', 'data', 'a', 'scalable', 'lightweight', 'bundling', 'method', 'for', 'parallel', 'coordinates']
# 과정4 title enWordsTokenStop(불용어 제거): ['visual', 'analysis', 'multidimensional', 'big', 'data', 'scalable', 'lightweight', 'bundling', 'method', 'parallel', 'coordinates']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['visual', 'analysis', 'multidimensional', 'big', 'data', 'scalable', 'lightweight', 'bundling', 'method', 'parallel', 'coordinate']
# 과정1 title 원본: A new approach for accurate distributed cluster analysis for Big Data: competitive K-Means
# 과정2 title enWords(re: 대소문자남기기): A new approach for accurate distributed cluster analysis for Big Data competitive K Means
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'new', 'approach', 'for', 'accurate', 'distributed', 'cluster', 'analysis', 'for', 'big', 'data', 'competitive', 'k', 'means']
# 과정4 title enWordsTokenStop(불용어 제거): ['new', 'approach', 'accurate', 'distributed', 'cluster', 'analysis', 'big', 'data', 'competitive', 'k', 'means']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['new', 'approach', 'accurate', 'distributed', 'cluster', 'analysis', 'big', 'data', 'competitive', 'k', 'mean']
# 과정1 title 원본: The Reliability of Big “Patient Satisfaction” Data
# 과정2 title enWords(re: 대소문자남기기): The Reliability of Big Patient Satisfaction Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'reliability', 'of', 'big', 'patient', 'satisfaction', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['reliability', 'big', 'patient', 'satisfaction', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['reliability', 'big', 'patient', 'satisfaction', 'data']
# 과정1 title 원본: Big data and analytics: a data management perspective in public administration
# 과정2 title enWords(re: 대소문자남기기): Big data and analytics a data management perspective in public administration
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'and', 'analytics', 'a', 'data', 'management', 'perspective', 'in', 'public', 'administration']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analytics', 'data', 'management', 'perspective', 'public', 'administration']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analytics', 'data', 'management', 'perspective', 'public', 'administration']
# 과정1 title 원본: Big Data and Disease Prevention: From Quantified Self to Quantified Communities
# 과정2 title enWords(re: 대소문자남기기): Big Data and Disease Prevention From Quantified Self to Quantified Communities
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'and', 'disease', 'prevention', 'from', 'quantified', 'self', 'to', 'quantified', 'communities']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'disease', 'prevention', 'quantified', 'self', 'quantified', 'communities']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'disease', 'prevention', 'quantified', 'self', 'quantified', 'community']
# 과정1 title 원본: The U.S. Army Person-Event Data Environment: A MilitaryÃƒÂ¢Ã¢â€šÂ¬Ã¢â‚¬Å“Civilian Big Data Enterprise
# 과정2 title enWords(re: 대소문자남기기): The U S Army Person Event Data Environment A Military Civilian Big Data Enterprise
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'u', 's', 'army', 'person', 'event', 'data', 'environment', 'a', 'military', 'civilian', 'big', 'data', 'enterprise']
# 과정4 title enWordsTokenStop(불용어 제거): ['u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise']
# 과정1 title 원본: Implications of Big Data Analytics on Population Health Management
# 과정2 title enWords(re: 대소문자남기기): Implications of Big Data Analytics on Population Health Management
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['implications', 'of', 'big', 'data', 'analytics', 'on', 'population', 'health', 'management']
# 과정4 title enWordsTokenStop(불용어 제거): ['implications', 'big', 'data', 'analytics', 'population', 'health', 'management']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['implication', 'big', 'data', 'analytics', 'population', 'health', 'management']
# 과정1 title 원본: XDataExplorer: A Three-Stage Comprehensive Self-Tuning Tool for Big Data Platforms
# 과정2 title enWords(re: 대소문자남기기): XDataExplorer A Three Stage Comprehensive Self Tuning Tool for Big Data Platforms
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['xdataexplorer', 'a', 'three', 'stage', 'comprehensive', 'self', 'tuning', 'tool', 'for', 'big', 'data', 'platforms']
# 과정4 title enWordsTokenStop(불용어 제거): ['xdataexplorer', 'three', 'stage', 'comprehensive', 'self', 'tuning', 'tool', 'big', 'data', 'platforms']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['xdataexplorer', 'three', 'stage', 'comprehensive', 'self', 'tuning', 'tool', 'big', 'data', 'platform']
# 과정1 title 원본: Big data in support of the Sustainable Development Goals: a celebration of the establishment of the International Research Center of Big Data for Sustainable Development Goals (CBAS)
# 과정2 title enWords(re: 대소문자남기기): Big data in support of the Sustainable Development Goals a celebration of the establishment of the International Research Center of Big Data for Sustainable Development Goals CBAS
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'in', 'support', 'of', 'the', 'sustainable', 'development', 'goals', 'a', 'celebration', 'of', 'the', 'establishment', 'of', 'the', 'international', 'research', 'center', 'of', 'big', 'data', 'for', 'sustainable', 'development', 'goals', 'cbas']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'support', 'sustainable', 'development', 'goals', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goals', 'cbas']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'support', 'sustainable', 'development', 'goal', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas']
# 과정1 title 원본: A Big Data Framework to Address Building Sum Insured Misestimation
# 과정2 title enWords(re: 대소문자남기기): A Big Data Framework to Address Building Sum Insured Misestimation
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'big', 'data', 'framework', 'to', 'address', 'building', 'sum', 'insured', 'misestimation']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'framework', 'address', 'building', 'sum', 'insured', 'misestimation']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'framework', 'address', 'building', 'sum', 'insured', 'misestimation']
# 과정1 title 원본: Furthest-Pair-Based Binary Search Tree for Speeding Big Data Classification Using K-Nearest Neighbors
# 과정2 title enWords(re: 대소문자남기기): Furthest Pair Based Binary Search Tree for Speeding Big Data Classification Using K Nearest Neighbors
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['furthest', 'pair', 'based', 'binary', 'search', 'tree', 'for', 'speeding', 'big', 'data', 'classification', 'using', 'k', 'nearest', 'neighbors']
# 과정4 title enWordsTokenStop(불용어 제거): ['furthest', 'pair', 'based', 'binary', 'search', 'tree', 'speeding', 'big', 'data', 'classification', 'using', 'k', 'nearest', 'neighbors']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['furthest', 'pair', 'based', 'binary', 'search', 'tree', 'speeding', 'big', 'data', 'classification', 'using', 'k', 'nearest', 'neighbor']
# 과정1 title 원본: Getting the Dirt on Big Data
# 과정2 title enWords(re: 대소문자남기기): Getting the Dirt on Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['getting', 'the', 'dirt', 'on', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['getting', 'dirt', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['getting', 'dirt', 'big', 'data']
# 과정1 title 원본: Call for Special Issue Papers: Big Data and the Internet-of-Things in Complex Information Systems: Selections from IoTBDS 2022 and COMPLEXIS 2022
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data and the Internet of Things in Complex Information Systems Selections from IoTBDS and COMPLEXIS
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'and', 'the', 'internet', 'of', 'things', 'in', 'complex', 'information', 'systems', 'selections', 'from', 'iotbds', 'and', 'complexis']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'internet', 'things', 'complex', 'information', 'systems', 'selections', 'iotbds', 'complexis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'internet', 'thing', 'complex', 'information', 'system', 'selection', 'iotbds', 'complexis']
# 과정1 title 원본: An Efficient, Ensemble-Based Classification Framework for Big Medical Data
# 과정2 title enWords(re: 대소문자남기기): An Efficient Ensemble Based Classification Framework for Big Medical Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['an', 'efficient', 'ensemble', 'based', 'classification', 'framework', 'for', 'big', 'medical', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['efficient', 'ensemble', 'based', 'classification', 'framework', 'big', 'medical', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['efficient', 'ensemble', 'based', 'classification', 'framework', 'big', 'medical', 'data']
# 과정1 title 원본: Call for Special Issue Papers: Multimedia Big Data Analytics for Engineering Education
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Multimedia Big Data Analytics for Engineering Education
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'multimedia', 'big', 'data', 'analytics', 'for', 'engineering', 'education']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education']
# 과정1 title 원본: Call for Special Issue Papers: Big Data in Business
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data in Business
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'in', 'business']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'business']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'business']
# 과정1 title 원본: Optimal Feature Selection for Big Data Classification: Firefly with Lion-Assisted Model
# 과정2 title enWords(re: 대소문자남기기): Optimal Feature Selection for Big Data Classification Firefly with Lion Assisted Model
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['optimal', 'feature', 'selection', 'for', 'big', 'data', 'classification', 'firefly', 'with', 'lion', 'assisted', 'model']
# 과정4 title enWordsTokenStop(불용어 제거): ['optimal', 'feature', 'selection', 'big', 'data', 'classification', 'firefly', 'lion', 'assisted', 'model']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['optimal', 'feature', 'selection', 'big', 'data', 'classification', 'firefly', 'lion', 'assisted', 'model']
# 과정1 title 원본: Call for Special Issue Papers: Deep Learning Assisted Big Data Analytics for Biomedical Applications and Digital Healthcare
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Deep Learning Assisted Big Data Analytics for Biomedical Applications and Digital Healthcare
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'deep', 'learning', 'assisted', 'big', 'data', 'analytics', 'for', 'biomedical', 'applications', 'and', 'digital', 'healthcare']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'deep', 'learning', 'assisted', 'big', 'data', 'analytics', 'biomedical', 'applications', 'digital', 'healthcare']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'deep', 'learning', 'assisted', 'big', 'data', 'analytics', 'biomedical', 'application', 'digital', 'healthcare']
# 과정1 title 원본: Deep Learning on Big, Sparse, Behavioral Data
# 과정2 title enWords(re: 대소문자남기기): Deep Learning on Big Sparse Behavioral Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['deep', 'learning', 'on', 'big', 'sparse', 'behavioral', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['deep', 'learning', 'big', 'sparse', 'behavioral', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['deep', 'learning', 'big', 'sparse', 'behavioral', 'data']
# 과정1 title 원본: A comparison on scalability for batch big data processing on Apache Spark and Apache Flink
# 과정2 title enWords(re: 대소문자남기기): A comparison on scalability for batch big data processing on Apache Spark and Apache Flink
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'comparison', 'on', 'scalability', 'for', 'batch', 'big', 'data', 'processing', 'on', 'apache', 'spark', 'and', 'apache', 'flink']
# 과정4 title enWordsTokenStop(불용어 제거): ['comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink']
# 과정1 title 원본: Data behaviours model for Big Data visual analytics
# 과정2 title enWords(re: 대소문자남기기): Data behaviours model for Big Data visual analytics
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['data', 'behaviours', 'model', 'for', 'big', 'data', 'visual', 'analytics']
# 과정4 title enWordsTokenStop(불용어 제거): ['data', 'behaviours', 'model', 'big', 'data', 'visual', 'analytics']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['data', 'behaviour', 'model', 'big', 'data', 'visual', 'analytics']
# 과정1 title 원본: Call for Special Issue Papers: Multimedia Big Data Analytics for Engineering Education
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Multimedia Big Data Analytics for Engineering Education
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'multimedia', 'big', 'data', 'analytics', 'for', 'engineering', 'education']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education']
# 과정1 title 원본: Interview with Dr. Silvio Carta, Author of the Book Big Data, Code and the Discrete City (Routledge 2019)
# 과정2 title enWords(re: 대소문자남기기): Interview with Dr Silvio Carta Author of the Book Big Data Code and the Discrete City Routledge
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['interview', 'with', 'dr', 'silvio', 'carta', 'author', 'of', 'the', 'book', 'big', 'data', 'code', 'and', 'the', 'discrete', 'city', 'routledge']
# 과정4 title enWordsTokenStop(불용어 제거): ['interview', 'dr', 'silvio', 'carta', 'author', 'book', 'big', 'data', 'code', 'discrete', 'city', 'routledge']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['interview', 'dr', 'silvio', 'carta', 'author', 'book', 'big', 'data', 'code', 'discrete', 'city', 'routledge']
# 과정1 title 원본: Call for Special Issue Papers: Soft Computing Models for Big Data and Internet of Things
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Soft Computing Models for Big Data and Internet of Things
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'soft', 'computing', 'models', 'for', 'big', 'data', 'and', 'internet', 'of', 'things']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'soft', 'computing', 'models', 'big', 'data', 'internet', 'things']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'soft', 'computing', 'model', 'big', 'data', 'internet', 'thing']
# 과정1 title 원본: SecDedoop: Secure Deduplication with Access Control of Big Data in the HDFS/Hadoop Environment
# 과정2 title enWords(re: 대소문자남기기): SecDedoop Secure Deduplication with Access Control of Big Data in the HDFS Hadoop Environment
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['secdedoop', 'secure', 'deduplication', 'with', 'access', 'control', 'of', 'big', 'data', 'in', 'the', 'hdfs', 'hadoop', 'environment']
# 과정4 title enWordsTokenStop(불용어 제거): ['secdedoop', 'secure', 'deduplication', 'access', 'control', 'big', 'data', 'hdfs', 'hadoop', 'environment']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['secdedoop', 'secure', 'deduplication', 'access', 'control', 'big', 'data', 'hdfs', 'hadoop', 'environment']
# 과정1 title 원본: Call for Special Issue Papers: Cloud Computing and Big Data for Cognitive IoT
# ...
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'based', 'attack', 'scenario', 'reconstruction', 'architecture', 'smart', 'grid']
# 과정1 title 원본: Big Data: A case study of disruption and government power
# 과정2 title enWords(re: 대소문자남기기): Big Data A case study of disruption and government power
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'a', 'case', 'study', 'of', 'disruption', 'and', 'government', 'power']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'case', 'study', 'disruption', 'government', 'power']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'case', 'study', 'disruption', 'government', 'power']
# 과정1 title 원본: Big Data: Theoretical Aspects
# 과정2 title enWords(re: 대소문자남기기): Big Data Theoretical Aspects
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'theoretical', 'aspects']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'theoretical', 'aspects']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'theoretical', 'aspect']
# 과정1 title 원본: Big Ideas or Big Data? [President's Message]
# 과정2 title enWords(re: 대소문자남기기): Big Ideas or Big Data President s Message
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'ideas', 'or', 'big', 'data', 'president', 's', 'message']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'ideas', 'big', 'data', 'president', 'message']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'idea', 'big', 'data', 'president', 'message']
# 과정1 title 원본: Big Data: Herausforderungen und Potenziale für deutsche Softwareunternehmen
# 과정2 title enWords(re: 대소문자남기기): Big Data Herausforderungen und Potenziale f r deutsche Softwareunternehmen
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'herausforderungen', 'und', 'potenziale', 'f', 'r', 'deutsche', 'softwareunternehmen']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'herausforderungen', 'und', 'potenziale', 'f', 'r', 'deutsche', 'softwareunternehmen']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'herausforderungen', 'und', 'potenziale', 'f', 'r', 'deutsche', 'softwareunternehmen']
# 과정1 title 원본: BIG DATA and Data-Driven Intelligent Predictive Algorithms to support creativity in Industrial Engineering
# 과정2 title enWords(re: 대소문자남기기): BIG DATA and Data Driven Intelligent Predictive Algorithms to support creativity in Industrial Engineering
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'and', 'data', 'driven', 'intelligent', 'predictive', 'algorithms', 'to', 'support', 'creativity', 'in', 'industrial', 'engineering']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'data', 'driven', 'intelligent', 'predictive', 'algorithms', 'support', 'creativity', 'industrial', 'engineering']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'data', 'driven', 'intelligent', 'predictive', 'algorithm', 'support', 'creativity', 'industrial', 'engineering']
# 과정1 title 원본: Big Data: A Survey
# 과정2 title enWords(re: 대소문자남기기): Big Data A Survey
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'a', 'survey']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'survey']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'survey']
# 과정1 title 원본: Big data: Little difference
# 과정2 title enWords(re: 대소문자남기기): Big data Little difference
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'little', 'difference']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'little', 'difference']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'little', 'difference']
# 과정1 title 원본: Big Data: A Cheerleader for Translational Perioperative Medicine
# 과정2 title enWords(re: 대소문자남기기): Big Data A Cheerleader for Translational Perioperative Medicine
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'a', 'cheerleader', 'for', 'translational', 'perioperative', 'medicine']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'cheerleader', 'translational', 'perioperative', 'medicine']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'cheerleader', 'translational', 'perioperative', 'medicine']
# 과정1 title 원본: Big Data-Driven Marketing: How Machine Learning Outperforms Marketers' Gut-Feeling
# 과정2 title enWords(re: 대소문자남기기): Big Data Driven Marketing How Machine Learning Outperforms Marketers Gut Feeling
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'driven', 'marketing', 'how', 'machine', 'learning', 'outperforms', 'marketers', 'gut', 'feeling']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'driven', 'marketing', 'machine', 'learning', 'outperforms', 'marketers', 'gut', 'feeling']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'driven', 'marketing', 'machine', 'learning', 'outperforms', 'marketer', 'gut', 'feeling']
# 과정1 title 원본: Big Data-Revolution oder Datenhybris?
# 과정2 title enWords(re: 대소문자남기기): Big Data Revolution oder Datenhybris
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'revolution', 'oder', 'datenhybris']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'revolution', 'oder', 'datenhybris']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'revolution', 'oder', 'datenhybris']
# 과정1 title 원본: Big Data and the Ownership in Data: Recent Developments in Europe
# 과정2 title enWords(re: 대소문자남기기): Big Data and the Ownership in Data Recent Developments in Europe
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'and', 'the', 'ownership', 'in', 'data', 'recent', 'developments', 'in', 'europe']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'ownership', 'data', 'recent', 'developments', 'europe']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'ownership', 'data', 'recent', 'development', 'europe']
# 과정1 title 원본: Big data: Guest editorial
# 과정2 title enWords(re: 대소문자남기기): Big data Guest editorial
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'guest', 'editorial']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'guest', 'editorial']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'guest', 'editorial']
# 과정1 title 원본: Big Data: New Tricks for Econometrics
# 과정2 title enWords(re: 대소문자남기기): Big Data New Tricks for Econometrics
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'new', 'tricks', 'for', 'econometrics']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'new', 'tricks', 'econometrics']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'new', 'trick', 'econometrics']
# 과정1 title 원본: Big data: lessons for employers and employees
# 과정2 title enWords(re: 대소문자남기기): Big data lessons for employers and employees
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'lessons', 'for', 'employers', 'and', 'employees']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'lessons', 'employers', 'employees']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'lesson', 'employer', 'employee']
# 과정1 title 원본: Data-driven innovation: switching the perspective on Big Data
# 과정2 title enWords(re: 대소문자남기기): Data driven innovation switching the perspective on Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['data', 'driven', 'innovation', 'switching', 'the', 'perspective', 'on', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['data', 'driven', 'innovation', 'switching', 'perspective', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['data', 'driven', 'innovation', 'switching', 'perspective', 'big', 'data']
# 과정1 title 원본: Big Data-Scoring unter dem Einfluss der Datenschutz-Grundverordnung
# 과정2 title enWords(re: 대소문자남기기): Big Data Scoring unter dem Einfluss der Datenschutz Grundverordnung
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'scoring', 'unter', 'dem', 'einfluss', 'der', 'datenschutz', 'grundverordnung']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'scoring', 'unter', 'dem', 'einfluss', 'der', 'datenschutz', 'grundverordnung']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'scoring', 'unter', 'dem', 'einfluss', 'der', 'datenschutz', 'grundverordnung']
# 과정1 title 원본: Big Data: History, Current Status, and Challenges Going Forward
# 과정2 title enWords(re: 대소문자남기기): Big Data History Current Status and Challenges Going Forward
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'history', 'current', 'status', 'and', 'challenges', 'going', 'forward']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'history', 'current', 'status', 'challenges', 'going', 'forward']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'history', 'current', 'status', 'challenge', 'going', 'forward']
# 과정1 title 원본: “Big data” driven tech mining and ST&I management: an introduction
# 과정2 title enWords(re: 대소문자남기기):  Big data driven tech mining and ST I management an introduction
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'driven', 'tech', 'mining', 'and', 'st', 'i', 'management', 'an', 'introduction']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'driven', 'tech', 'mining', 'st', 'management', 'introduction']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'driven', 'tech', 'mining', 'st', 'management', 'introduction']
# 과정1 title 원본: Data: Big and Small
# 과정2 title enWords(re: 대소문자남기기): Data Big and Small
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['data', 'big', 'and', 'small']
# 과정4 title enWordsTokenStop(불용어 제거): ['data', 'big', 'small']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['data', 'big', 'small']
# 과정1 title 원본: Big Data. Big Problem?
# 과정2 title enWords(re: 대소문자남기기): Big Data Big Problem
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'big', 'problem']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'big', 'problem']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'big', 'problem']
# 과정1 title 원본: Data-Driven Decision Making in Precision Agriculture: The Rise of Big Data in Agricultural Systems
# 과정2 title enWords(re: 대소문자남기기): Data Driven Decision Making in Precision Agriculture The Rise of Big Data in Agricultural Systems
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['data', 'driven', 'decision', 'making', 'in', 'precision', 'agriculture', 'the', 'rise', 'of', 'big', 'data', 'in', 'agricultural', 'systems']
# 과정4 title enWordsTokenStop(불용어 제거): ['data', 'driven', 'decision', 'making', 'precision', 'agriculture', 'rise', 'big', 'data', 'agricultural', 'systems']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['data', 'driven', 'decision', 'making', 'precision', 'agriculture', 'rise', 'big', 'data', 'agricultural', 'system']
# 과정1 title 원본: Big data's big bias in drug safety
# 과정2 title enWords(re: 대소문자남기기): Big data s big bias in drug safety
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 's', 'big', 'bias', 'in', 'drug', 'safety']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'big', 'bias', 'drug', 'safety']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'big', 'bias', 'drug', 'safety']
# 과정1 title 원본: BIG BUCKS ARE BACKING BIG DATA'S LOBBYING EFFORTS ON CAPITOL HILL
# 과정2 title enWords(re: 대소문자남기기): BIG BUCKS ARE BACKING BIG DATA S LOBBYING EFFORTS ON CAPITOL HILL
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'bucks', 'are', 'backing', 'big', 'data', 's', 'lobbying', 'efforts', 'on', 'capitol', 'hill']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'bucks', 'backing', 'big', 'data', 'lobbying', 'efforts', 'capitol', 'hill']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'buck', 'backing', 'big', 'data', 'lobbying', 'effort', 'capitol', 'hill']
# 과정1 title 원본: 'Big data' approaches for novel anti-cancer drug discovery
# 과정2 title enWords(re: 대소문자남기기):  Big data approaches for novel anti cancer drug discovery
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'approaches', 'for', 'novel', 'anti', 'cancer', 'drug', 'discovery']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'approaches', 'novel', 'anti', 'cancer', 'drug', 'discovery']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'approach', 'novel', 'anti', 'cancer', 'drug', 'discovery']
# words(전처리, re 정규식, token화, stop 불용어 제거, 표제어 추출) : [['architecting', 'time', 'critical', 'big', 'data', 'system'], ['bold', 'bold', 'ense', 'bold', 'bold', 'r', 'bold', 'bold', 'parse', 'elastic', 'spmm', 'implementation', 'optimal', 'big', 'data', 'processing'], ['game', 'theoretic', 'approach', 'addressing', 'domain', 'shift', 'big', 'data'], ['trust', 'based', 'crowdfunding', 'campaign', 'marketing', 'framework', 'theoretical', 'underpinnings', 'big', 'data', 'analytics', 'practice'], ['computation', 'migration', 'new', 'approach', 'execute', 'big', 'data', 'bioinformatics', 'workflow'], ['big', 'data', 'small', 'persona', 'algorithm', 'shape', 'demographic', 'representation', 'data', 'driven', 'user', 'segment'], ['big', 'scholarly', 'data', 'survey'], ['data', 'efficient', 'performance', 'modeling', 'configurable', 'big', 'data', 'framework', 'reducing', 'information', 'overlap', 'training', 'example'], ['comment', 'revolution', 'transform', 'live', 'work', 'think', 'interview', 'author', 'big', 'data'], ['predictive', 'modeling', 'big', 'data', 'bigger', 'really', 'better'], ['scientific', 'training', 'era', 'big', 'data', 'new', 'pedagogy', 'graduate', 'education'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation'], ['scalable', 'data', 'quality', 'big', 'data', 'pythia', 'framework', 'handling', 'missing', 'value'], ['author', 'response', 'gong', 'comment', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation'], ['bring', 'big', 'data', 'beyond', 'hype'], ['correction', 'predictive', 'modeling', 'big', 'data', 'bigger', 'really', 'better', 'junqu', 'de', 'fortuny', 'e', 'marten', 'provost', 'f', 'big', 'data'], ['sport', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier'], ['sport', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier'], ['comment', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making'], ['multiple', 'target', 'tracking', 'big', 'data', 'based', 'measurement', 'extended', 'binary', 'phase', 'shift', 'keying', 'transceiver'], ['big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation'], ['big', 'data', 'new', 'method', 'idea', 'geological', 'scientific', 'research'], ['role', 'teamwork', 'analysis', 'big', 'data', 'study', 'visual', 'analytics', 'box', 'office', 'prediction'], ['global', 'water', 'cycle', 'remote', 'sensing', 'big', 'data', 'overview', 'challenge', 'opportunity'], ['deep', 'learning', 'processing', 'analysis', 'remote', 'sensing', 'big', 'data', 'technical', 'review'], ['data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation'], ['computational', 'propaganda', 'political', 'big', 'data', 'moving', 'toward', 'critical', 'research', 'agenda'], ['structural', 'consequence', 'big', 'data', 'driven', 'education'], ['software', 'architecture', 'big', 'data', 'systematic', 'literature', 'review'], ['diversity', 'big', 'data', 'review'], ['big', 'data', 'artificial', 'intelligence', 'fusion', 'technology', 'education', 'context', 'new', 'crown', 'epidemic'], ['mapping', 'essential', 'urban', 'land', 'use', 'category', 'euluc', 'using', 'geospatial', 'big', 'data', 'progress', 'challenge', 'opportunity'], ['capturing', 'value', 'biosurveillance', 'big', 'data', 'natural', 'capital', 'accounting'], ['big', 'boe', 'fusing', 'spanish', 'official', 'gazette', 'big', 'data', 'technology'], ['diastema', 'data', 'driven', 'stac ...

# %%
# 2차원 리스트 -> 1차원 리스트 , 차원 축소 
# reduce 함수 이용하기. 차원 축소 
# list 함수 이용해서, 1차원 리스트로 만들기. 
result = reduce(lambda x,y : x+y, words)
words2 = list(result)
#result
print(f"result 타입 조사 : {type(words2)}")
print(f"words2 : {words2}")
# Out:
# result 타입 조사 : <class 'list'>
# words2 : ['architecting', 'time', 'critical', 'big', 'data', 'system', 'bold', 'bold', 'ense', 'bold', 'bold', 'r', 'bold', 'bold', 'parse', 'elastic', 'spmm', 'implementation', 'optimal', 'big', 'data', 'processing', 'game', 'theoretic', 'approach', 'addressing', 'domain', 'shift', 'big', 'data', 'trust', 'based', 'crowdfunding', 'campaign', 'marketing', 'framework', 'theoretical', 'underpinnings', 'big', 'data', 'analytics', 'practice', 'computation', 'migration', 'new', 'approach', 'execute', 'big', 'data', 'bioinformatics', 'workflow', 'big', 'data', 'small', 'persona', 'algorithm', 'shape', 'demographic', 'representation', 'data', 'driven', 'user', 'segment', 'big', 'scholarly', 'data', 'survey', 'data', 'efficient', 'performance', 'modeling', 'configurable', 'big', 'data', 'framework', 'reducing', 'information', 'overlap', 'training', 'example', 'comment', 'revolution', 'transform', 'live', 'work', 'think', 'interview', 'author', 'big', 'data', 'predictive', 'modeling', 'big', 'data', 'bigger', 'really', 'better', 'scientific', 'training', 'era', 'big', 'data', 'new', 'pedagogy', 'graduate', 'education', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'scalable', 'data', 'quality', 'big', 'data', 'pythia', 'framework', 'handling', 'missing', 'value', 'author', 'response', 'gong', 'comment', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'bring', 'big', 'data', 'beyond', 'hype', 'correction', 'predictive', 'modeling', 'big', 'data', 'bigger', 'really', 'better', 'junqu', 'de', 'fortuny', 'e', 'marten', 'provost', 'f', 'big', 'data', 'sport', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier', 'sport', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier', 'comment', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making', 'multiple', 'target', 'tracking', 'big', 'data', 'based', 'measurement', 'extended', 'binary', 'phase', 'shift', 'keying', 'transceiver', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'big', 'data', 'new', 'method', 'idea', 'geological', 'scientific', 'research', 'role', 'teamwork', 'analysis', 'big', 'data', 'study', 'visual', 'analytics', 'box', 'office', 'prediction', 'global', 'water', 'cycle', 'remote', 'sensing', 'big', 'data', 'overview', 'challenge', 'opportunity', 'deep', 'learning', 'processing', 'analysis', 'remote', 'sensing', 'big', 'data', 'technical', 'review', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'computational', 'propaganda', 'political', 'big', 'data', 'moving', 'toward', 'critical', 'research', 'agenda', 'structural', 'consequence', 'big', 'data', 'driven', 'education', 'software', 'architecture', 'big', 'data', 'systematic', 'literature', 'review', 'diversity', 'big', 'data', 'review', 'big', 'data', 'artificial', 'intelligence', 'fusion', 'technology', 'education', 'context', 'new', 'crown', 'epidemic', 'mapping', 'essential', 'urban', 'land', 'use', 'category', 'euluc', 'using', 'geospatial', 'big', 'data', 'progress', 'challenge', 'opportunity', 'capturing', 'value', 'biosurveillance', 'big', 'data', 'natural', 'capital', 'accounting', 'big', 'boe', 'fusing', 'spanish', 'official', 'gazette', 'big', 'data', 'technology', 'diastema', 'data', 'driven', 'stack', 'big', 'data', 'application', 'management', 'deployment', 'big', 'data', 'based', 'rf', 'localisation', 'method' ...

# %%
# 데이터 탐색, 기본 분석 모델 만들기. 
# Counter -> 해당 단어 빈도 집계 해주는 함수. 
count = Counter(words2)
count
# Out:
# Counter({'data': 1226,
#          'big': 1103,
#          'analytics': 133,
#          'based': 117,
#          'analysis': 113,
#          'system': 68,
#          'driven': 68,
#          'using': 68,
#          'approach': 66,
#          'learning': 56,
#          'model': 55,
#          'issue': 53,
#          'application': 46,
#          'special': 42,
#          'management': 41,
#          'algorithm': 40,
#          'framework': 39,
#          'call': 36,
#          'science': 36,
#          'platform': 36,
#          'paper': 35,
#          'challenge': 34,
#          'network': 34,
#          'new': 33,
#          'cloud': 33,
#          'performance': 30,
#          'era': 30,
#          'health': 30,
#          'machine': 30,
#          'research': 29,
#          'review': 29,
#          'mining': 29,
#          'processing': 28,
#          'earth': 28,
#          'computing': 26,
#          'real': 26,
#          'perspective': 25,
#          'optimization': 25,
#          'world': 25,
#          'method': 24,
#          'study': 24,
#          'technology': 24,
#          'business': 24,
#          'service': 24,
#          'opportunity': 23,
#          'distributed': 23,
#          'survey': 22,
#          'efficient': 22,
#          'use': 21,
#          'medical': 21,
#          'intelligent': 21,
#          'time': 20,
#          'intelligence': 20,
#          'case': 20,
#          'smart': 20,
#          'information': 19,
#          'internet': 19,
#          'small': 18,
#          'development': 18,
#          'engineering': 18,
#          'healthcare': 18,
#          'high': 18,
#          'china': 18,
#          'energy': 18,
#          'deep': 17,
#          'editorial': 17,
#          'environment': 17,
#          'sustainable': 17,
#          'discovery': 17,
#          'industry': 17,
#          'process': 17,
#          'digital': 16,
#          'role': 16,
#          'medium': 16,
#          'thing': 16,
#          'social': 16,
#          'scalable': 15,
#          'architecture': 15,
#          'patient': 15,
#          'classification': 15,
#          'security': 15,
#          'impact': 15,
#          'detection': 15,
#          'future': 15,
#          'technique': 15,
#          'towards': 15,
#          'making': 14,
#          'prediction': 14,
#          'multi': 14,
#          'care': 14,
#          'practice': 13,
#          'modeling': 13,
#          'guest': 13,
#          'clustering': 13,
#          'monitoring': 13,
#          'online': 13,
#          'decision': 12,
#          'understanding': 12,
#          'goal': 12,
#          'evidence': 12,
#          'sharing': 12,
#          'human': 12,
#          'pattern': 12,
#          'spatial': 12,
#          'solution': 12,
#          'distribution': 12,
#          'revolution': 11,
#          'work': 11,
#          'context': 11,
#          'public': 11,
#          'support': 11,
#          'selection': 11,
#          'feature': 11,
#          'city': 11,
#          'iot': 11,
#          'infrastructure': 11,
#          'state': 11,
#          'risk': 11,
#          'problem': 11,
#          'design': 11,
#          'safety': 11,
#          'scientific': 10,
#          'quality': 10,
#          'computational': 10,
#          'privacy': 10,
#          'little': 10,
#          'market': 10,
#          'innovation': 10,
#          'capability': 10,
#          'memory': 10,
#          'transportation': 10,
#          'clinical': 10,
#          'chain': 10,
#          'recommendation': 10,
#          'scheduling': 10,
#          'via': 10,
#          'scale': 10,
#          'database': 10,
#          'r': 9,
#          'predictive': 9,
#          'education': 9,
#          'transformation': 9,
#          'value': 9,
#          'global': 9,
#          'sensing': 9,
#          'urban': 9,
#          'u': 9,
#          'enterprise': 9,
#          'implication': 9,
#          'building': 9,
#          'control': 9,
#          'industrial': 9,
#          'forecasting': 9,
#          'green': 9,
#          'aware': 9,
#          'power': 9,
#          'dynamic': 9,
#          'visualization': 9,
#          'knowledge': 9,
#          'disaster': 9,
#          'assessment': 9,
#          'novel': 9,
#          'supply': 9,
#          'trend': 9,
#          'storage': 9,
#          'large': 9,
#          'strategy': 9,
#          'insight': 9,
#          'think': 8,
#          'toward': 8,
#          'literature': 8,
#          'search': 8,
#          'parallel': 8,
#          'policy': 8,
#          'scheme': 8,
#          'evaluating': 8,
#          'covid': 8,
#          'sector': 8,
#          'financial': 8,
#          'exploring': 8,
#          'vehicle': 8,
#          'current': 8,
#          'potential': 8,
#          'semantic': 8,
#          'warehouse': 8,
#          'mapreduce': 8,
#          'device': 8,
#          'improve': 8,
#          'transform': 7,
#          'relationship': 7,
#          'measurement': 7,
#          'political': 7,
#          'k': 7,
#          'spark': 7,
#          'sensor': 7,
#          'firm': 7,
#          'index': 7,
#          'intensity': 7,
#          'flow': 7,
#          'error': 7,
#          'adaptive': 7,
#          'approximation': 7,
#          'material': 7,
#          'fuzzy': 7,
#          'statistical': 7,
#          'web': 7,
#          'leveraging': 7,
#          'company': 7,
#          'enabled': 7,
#          'way': 7,
#          'behavior': 7,
#          'communication': 7,
#          'advanced': 7,
#          'uncertainty': 7,
#          'drug': 7,
#          'generation': 7,
#          'government': 7,
#          'production': 7,
#          'nasopharyngeal': 7,
#          'carcinoma': 7,
#          'radiotherapy': 7,
#          'scholarship': 7,
#          'critical': 6,
#          'bold': 6,
#          'user': 6,
#          'live': 6,
#          'interview': 6,
#          'e': 6,
#          'next': 6,
#          'software': 6,
#          'mapping': 6,
#          'disease': 6,
#          'self': 6,
#          'tool': 6,
#          'international': 6,
#          'center': 6,
#          'assisted': 6,
#          'access': 6,
#          'project': 6,
#          'effect': 6,
#          'grid': 6,
#          'medicine': 6,
#          'enhanced': 6,
#          'space': 6,
#          'traffic': 6,
#          'national': 6,
#          'factor': 6,
#          'optimizing': 6,
#          'age': 6,
#          'evolution': 6,
#          'query': 6,
#          'finding': 6,
#          'resource': 6,
#          'analyzing': 6,
#          'anomaly': 6,
#          'governance': 6,
#          'estimation': 6,
#          'identification': 6,
#          'benefit': 6,
#          'compression': 6,
#          'team': 6,
#          'oriented': 6,
#          'efficiency': 6,
#          'text': 6,
#          'networked': 6,
#          'implementation': 5,
#          'marketing': 5,
#          'scholarly': 5,
#          'better': 5,
#          'futuristic': 5,
#          'fabric': 5,
#          'societal': 5,
#          'correction': 5,
#          'moving': 5,
#          'multiple': 5,
#          'visual': 5,
#          'remote': 5,
#          'fusion': 5,
#          'accurate': 5,
#          'cluster': 5,
#          'competitive': 5,
#          'mean': 5,
#          'comprehensive': 5,
#          'complex': 5,
#          'ensemble': 5,
#          'apache': 5,
#          'electric': 5,
#          'report': 5,
#          'cybersecurity': 5,
#          'neural': 5,
#          'series': 5,
#          'utilization': 5,
#          'observation': 5,
#          'sentiment': 5,
#          'theory': 5,
#          'recent': 5,
#          'united': 5,
#          'deal': 5,
#          'key': 5,
#          'agricultural': 5,
#          'reference': 5,
#          'improved': 5,
#          'price': 5,
#          'regional': 5,
#          'collaboration': 5,
#          'allocation': 5,
#          'content': 5,
#          'mobility': 5,
#          'heterogeneous': 5,
#          'operation': 5,
#          'hybrid': 5,
#          'kernel': 5,
#          'view': 5,
#          'geo': 5,
#          'graph': 5,
#          'integration': 5,
#          'meet': 5,
#          'paradigm': 5,
#          'wireless': 5,
#          'evaluation': 5,
#          'logistics': 5,
#          'manufacturing': 5,
#          'predicting': 5,
#          'product': 5,
#          'non': 5,
#          'field': 5,
#          'promise': 5,
#          'question': 5,
#          'environmental': 5,
#          'offer': 5,
#          'help': 5,
#          'dementia': 5,
#          'theoretical': 4,
#          'workflow': 4,
#          'reducing': 4,
#          'training': 4,
#          'author': 4,
#          'bigger': 4,
#          'handling': 4,
#          'frontier': 4,
#          'tracking': 4,
#          'phase': 4,
#          'overview': 4,
#          'structural': 4,
#          'artificial': 4,
#          'community': 4,
#          'nearest': 4,
#          'multimedia': 4,
#          'behavioral': 4,
#          'secure': 4,
#          'cognitive': 4,
#          'good': 4,
#          'temporal': 4,
#          'preserving': 4,
#          'innovative': 4,
#          'initiative': 4,
#          'failure': 4,
#          'bibliometric': 4,
#          'finance': 4,
#          'status': 4,
#          'gathering': 4,
#          'encryption': 4,
#          'stock': 4,
#          'early': 4,
#          'warning': 4,
#          'experience': 4,
#          'advance': 4,
#          'image': 4,
#          'map': 4,
#          'multimodal': 4,
#          'telecom': 4,
#          'investigation': 4,
#          'emerging': 4,
#          'set': 4,
#          'general': 4,
#          'diagnosis': 4,
#          'news': 4,
#          'tensor': 4,
#          'deadline': 4,
#          'make': 4,
#          'mobile': 4,
#          'message': 4,
#          'demand': 4,
#          'organizational': 4,
#          'dimensional': 4,
#          'random': 4,
#          'sleep': 4,
#          'strategic': 4,
#          'commerce': 4,
#          'stream': 4,
#          'nosql': 4,
#          'life': 4,
#          'managing': 4,
#          'pipeline': 4,
#          'matrix': 4,
#          'processor': 4,
#          'semantics': 4,
#          'open': 4,
#          'sampling': 4,
#          'bayesian': 4,
#          'transforming': 4,
#          'practical': 4,
#          'ai': 4,
#          'used': 4,
#          'physical': 4,
#          'cell': 4,
#          'applying': 4,
#          'incremental': 4,
#          'methodology': 4,
#          'supporting': 4,
#          'dimension': 4,
#          'v': 4,
#          'group': 4,
#          'advantage': 4,
#          'car': 4,
#          'law': 4,
#          'student': 4,
#          'gene': 4,
#          'der': 4,
#          'lesson': 4,
#          'emergence': 4,
#          'discussion': 4,
#          'informatics': 4,
#          'politics': 4,
#          'cancer': 4,
#          'tourism': 4,
#          'area': 4,
#          'und': 4,
#          'biology': 4,
#          'stochastic': 4,
#          'cost': 4,
#          'p': 4,
#          'top': 4,
#          'modulated': 4,
#          'provides': 4,
#          'pp': 4,
#          'isbn': 4,
#          'optimal': 3,
#          'domain': 3,
#          'shift': 3,
#          'computation': 3,
#          'comment': 3,
#          'really': 3,
#          'response': 3,
#          'de': 3,
#          'f': 3,
#          'sport': 3,
#          'extended': 3,
#          'water': 3,
#          'propaganda': 3,
#          'geospatial': 3,
#          'natural': 3,
#          'biomedical': 3,
#          'quantified': 3,
#          'population': 3,
#          'three': 3,
#          'stage': 3,
#          'tree': 3,
#          'neighbor': 3,
#          'sparse': 3,
#          'code': 3,
#          'deduplication': 3,
#          'hadoop': 3,
#          'school': 3,
#          'exploiting': 3,
#          'cooperative': 3,
#          'tech': 3,
#          'dual': 3,
#          'moderating': 3,
#          'gaussian': 3,
#          'streaming': 3,
#          'pervasive': 3,
#          'long': 3,
#          'attribute': 3,
#          'proxy': 3,
#          'low': 3,
#          'stakeholder': 3,
#          'gi': 3,
#          'analytical': 3,
#          'change': 3,
#          'quantifying': 3,
#          'insurance': 3,
#          'record': 3,
#          'metadata': 3,
#          'comparative': 3,
#          'reduce': 3,
#          'c': 3,
#          'resistance': 3,
#          'operational': 3,
#          'interactive': 3,
#          'college': 3,
#          'region': 3,
#          'level': 3,
#          'fine': 3,
#          'credit': 3,
#          'unstructured': 3,
#          'conceptual': 3,
#          'perception': 3,
#          'programming': 3,
#          'measure': 3,
#          'focus': 3,
#          'filter': 3,
#          'continued': 3,
#          'robotics': 3,
#          'improving': 3,
#          'consumption': 3,
#          'interval': 3,
#          'patent': 3,
#          'diabetes': 3,
#          'scholar': 3,
#          'landscape': 3,
#          'edge': 3,
#          'increased': 3,
#          'customer': 3,
#          'bias': 3,
#          'co': 3,
#          'swarm': 3,
#          'taxi': 3,
#          'independent': 3,
#          'rating': 3,
#          'classifier': 3,
#          'simulation': 3,
#          'evolving': 3,
#          'extraction': 3,
#          'five': 3,
#          'corporate': 3,
#          'fast': 3,
#          'concern': 3,
#          'air': 3,
#          'flexible': 3,
#          'barrier': 3,
#          'smes': 3,
#          'factorization': 3,
#          'core': 3,
#          'generalized': 3,
#          'google': 3,
#          'engine': 3,
#          'compute': 3,
#          'transfer': 3,
#          'blood': 3,
#          'biggest': 3,
#          'leverage': 3,
#          'collection': 3,
#          'reduction': 3,
#          'dream': 3,
#          'rule': 3,
#          'scenario': 3,
#          'determinant': 3,
#          'developmental': 3,
#          'relation': 3,
#          'mechanism': 3,
#          'economy': 3,
#          'construction': 3,
#          'twitter': 3,
#          'store': 3,
#          'genome': 3,
#          'aggregation': 3,
#          'correlation': 3,
#          'course': 3,
#          'candidate': 3,
#          'x': 3,
#          'individual': 3,
#          'type': 3,
#          'structure': 3,
#          'carbon': 3,
#          'spectrum': 3,
#          'growth': 3,
#          'oil': 3,
#          'screening': 3,
#          'pandemic': 3,
#          'ethic': 3,
#          'child': 3,
#          'activity': 3,
#          'pain': 3,
#          'ecology': 3,
#          'dissemination': 3,
#          'ground': 3,
#          'pressure': 3,
#          'need': 3,
#          'gpu': 3,
#          'nonvolatile': 3,
#          'interconnection': 3,
#          'exascale': 3,
#          'zum': 3,
#          'ownership': 3,
#          'mit': 3,
#          'unit': 3,
#          'anti': 3,
#          'wide': 3,
#          'association': 3,
#          'among': 3,
#          'therapy': 3,
#          'action': 3,
#          'introduction': 3,
#          'audit': 3,
#          'asia': 3,
#          'anatomy': 3,
#          'hospital': 3,
#          'associated': 3,
#          'donepezil': 3,
#          'comorbidity': 3,
#          'alzheimer': 3,
#          'japan': 3,
#          'marketer': 3,
#          'internal': 3,
#          'gain': 3,
#          'lawyer': 3,
#          'christine': 3,
#          'l': 3,
#          'borgman': 3,
#          'press': 3,
#          'create': 3,
#          'optimize': 3,
#          'pediatric': 3,
#          'intensive': 3,
#          'brother': 3,
#          'personalized': 3,
#          'geoinformatics': 3,
#          'elastic': 2,
#          'theoretic': 2,
#          'addressing': 2,
#          'crowdfunding': 2,
#          'campaign': 2,
#          'bioinformatics': 2,
#          'demographic': 2,
#          'graduate': 2,
#          'hype': 2,
#          'target': 2,
#          'binary': 2,
#          'idea': 2,
#          'cycle': 2,
#          'agenda': 2,
#          'land': 2,
#          'progress': 2,
#          'capturing': 2,
#          'capital': 2,
#          'stack': 2,
#          'unmanned': 2,
#          'part': 2,
#          'interdisciplinary': 2,
#          'lightweight': 2,
#          'reliability': 2,
#          'prevention': 2,
#          'army': 2,
#          'event': 2,
#          'tuning': 2,
#          'celebration': 2,
#          'establishment': 2,
#          'cbas': 2,
#          'getting': 2,
#          'comparison': 2,
#          'batch': 2,
#          'flink': 2,
#          'soft': 2,
#          'order': 2,
#          'aging': 2,
#          'grey': 2,
#          'drive': 2,
#          'fundamental': 2,
#          'disruption': 2,
#          'biological': 2,
#          'coverage': 2,
#          'labor': 2,
#          'get': 2,
#          'condition': 2,
#          'common': 2,
#          'overcome': 2,
#          'spatio': 2,
#          'intrusion': 2,
#          'heart': 2,
#          'startup': 2,
#          'univariate': 2,
#          'optimized': 2,
#          'routing': 2,
#          'gated': 2,
#          'short': 2,
#          'term': 2,
#          'ring': 2,
#          'homomorphic': 2,
#          'restaurant': 2,
#          'setting': 2,
#          'analyze': 2,
#          'discrimination': 2,
#          'unlocking': 2,
#          'institute': 2,
#          'climate': 2,
#          'agency': 2,
#          'channel': 2,
#          'sentinel': 2,
#          'coming': 2,
#          'made': 2,
#          'simple': 2,
#          'catalyst': 2,
#          'rise': 2,
#          'related': 2,
#          'belt': 2,
#          'moth': 2,
#          'flame': 2,
#          'bat': 2,
#          'ecosystem': 2,
#          'ranking': 2,
#          'ocean': 2,
#          'mediating': 2,
#          'assurance': 2,
#          'relevant': 2,
#          'within': 2,
#          'objective': 2,
#          'evolutionary': 2,
#          'differential': 2,
#          'maintenance': 2,
#          'localization': 2,
#          'blending': 2,
#          'position': 2,
#          'fmri': 2,
#          'exchange': 2,
#          'enabler': 2,
#          'primary': 2,
#          'compliance': 2,
#          'mr': 2,
#          'lost': 2,
#          'aerial': 2,
#          'strength': 2,
#          'reinforcement': 2,
#          'editor': 2,
#          'commercial': 2,
#          'modelling': 2,
#          'sorting': 2,
#          'centric': 2,
#          'station': 2,
#          'property': 2,
#          'utilizing': 2,
#          'estate': 2,
#          'partitioning': 2,
#          'congestion': 2,
#          'resiliency': 2,
#          'prescription': 2,
#          'influence': 2,
#          'extending': 2,
#          'grouping': 2,
#          'datasets': 2,
#          'sustainability': 2,
#          'uk': 2,
#          'approximate': 2,
#          'balance': 2,
#          'shared': 2,
#          'thermal': 2,
#          'task': 2,
#          'provision': 2,
#          'semantically': 2,
#          'reconstruction': 2,
#          'hierarchical': 2,
#          'forest': 2,
#          'layer': 2,
#          'eeg': 2,
#          'extracting': 2,
#          'searching': 2,
#          'consistency': 2,
#          'fraud': 2,
#          'trajectory': 2,
#          'ethical': 2,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'causality': 2,
#          'functional': 2,
#          'qualitative': 2,
#          'situation': 2,
#          'awareness': 2,
#          'tutorial': 2,
#          'similarity': 2,
#          'banking': 2,
#          'structured': 2,
#          'svm': 2,
#          'vector': 2,
#          'cube': 2,
#          'interoperability': 2,
#          'australian': 2,
#          'ontology': 2,
#          'supervised': 2,
#          'transport': 2,
#          'alternative': 2,
#          'first': 2,
#          'landsat': 2,
#          'ship': 2,
#          'labeling': 2,
#          'donation': 2,
#          'repository': 2,
#          'coping': 2,
#          'culture': 2,
#          'regression': 2,
#          'divide': 2,
#          'organisation': 2,
#          'maturity': 2,
#          'yield': 2,
#          'designing': 2,
#          'mine': 2,
#          'automated': 2,
#          'build': 2,
#          'em': 2,
#          'theme': 2,
#          'volume': 2,
#          'electrophysiology': 2,
#          'exploration': 2,
#          'criminal': 2,
#          'portfolio': 2,
#          'cyber': 2,
#          'grand': 2,
#          'conference': 2,
#          'experimental': 2,
#          'securing': 2,
#          'academic': 2,
#          'skill': 2,
#          'library': 2,
#          'peer': 2,
#          'belief': 2,
#          'pharmaceutical': 2,
#          'michael': 2,
#          'buck': 2,
#          'convergent': 2,
#          'modern': 2,
#          'matching': 2,
#          'analysing': 2,
#          'path': 2,
#          'success': 2,
#          'advancing': 2,
#          'comparing': 2,
#          'direction': 2,
#          'virtual': 2,
#          'sequence': 2,
#          'sample': 2,
#          'conflict': 2,
#          'pre': 2,
#          'join': 2,
#          'decomposition': 2,
#          'effective': 2,
#          'recovery': 2,
#          'dataset': 2,
#          'free': 2,
#          'imputation': 2,
#          'face': 2,
#          'simplified': 2,
#          'mo': 2,
#          'working': 2,
#          'oracle': 2,
#          'sparc': 2,
#          'also': 2,
#          'ready': 2,
#          'program': 2,
#          'account': 2,
#          'imaging': 2,
#          'stem': 2,
#          'track': 2,
#          'expression': 2,
#          'protein': 2,
#          'boost': 2,
#          'influencing': 2,
#          'empirical': 2,
#          'satellite': 2,
#          'film': 2,
#          'concept': 2,
#          'scanning': 2,
#          'throughput': 2,
#          'variation': 2,
#          'genomics': 2,
#          'smallholder': 2,
#          'neuroimaging': 2,
#          'informed': 2,
#          'disorder': 2,
#          'surface': 2,
#          'fitting': 2,
#          'aircraft': 2,
#          'cryptography': 2,
#          'measuring': 2,
#          'job': 2,
#          'employee': 2,
#          'rhetoric': 2,
#          'worker': 2,
#          'targeted': 2,
#          'available': 2,
#          'doi': 2,
#          'researcher': 2,
#          'say': 2,
#          'becoming': 2,
#          'savvy': 2,
#          'animal': 2,
#          'south': 2,
#          'korea': 2,
#          'art': 2,
#          'edited': 2,
#          'bike': 2,
#          'st': 2,
#          'still': 2,
#          'expanding': 2,
#          'cover': 2,
#          'putting': 2,
#          'detect': 2,
#          'career': 2,
#          'charging': 2,
#          'pmu': 2,
#          'workload': 2,
#          'enhancing': 2,
#          'waste': 2,
#          'jbhi': 2,
#          'w': 2,
#          'pitfall': 2,
#          'phylogenetics': 2,
#          'convergence': 2,
#          'seeking': 2,
#          'dividend': 2,
#          'joining': 2,
#          'eva': 2,
#          'style': 2,
#          'randomized': 2,
#          'must': 2,
#          'emergency': 2,
#          'planning': 2,
#          'hat': 2,
#          'readiness': 2,
#          'mode': 2,
#          'jd': 2,
#          'com': 2,
#          'identifying': 2,
#          'purpose': 2,
#          'thema': 2,
#          'pr': 2,
#          'analyse': 2,
#          'digitalization': 2,
#          'diffusion': 2,
#          'wcn': 2,
#          'genetic': 2,
#          'brain': 2,
#          'creation': 2,
#          'forward': 2,
#          'leadership': 2,
#          'hacker': 2,
#          'behave': 2,
#          'travel': 2,
#          'distance': 2,
#          'inference': 2,
#          'stability': 2,
#          'convex': 2,
#          'endemic': 2,
#          'statistic': 2,
#          'singapore': 2,
#          'mhc': 2,
#          'crunch': 2,
#          'trade': 2,
#          'versus': 2,
#          'mortality': 2,
#          'admission': 2,
#          'reported': 2,
#          'outcome': 2,
#          'centered': 2,
#          'article': 2,
#          'reward': 2,
#          'improvement': 2,
#          'mental': 2,
#          'generated': 2,
#          'creating': 2,
#          'epidemiology': 2,
#          'size': 2,
#          'treatment': 2,
#          'survival': 2,
#          'total': 2,
#          'locoregionally': 2,
#          'filtering': 2,
#          'across': 2,
#          'utility': 2,
#          'reram': 2,
#          'tcam': 2,
#          'frequent': 2,
#          'instant': 2,
#          'noise': 2,
#          'pay': 2,
#          'swd': 2,
#          'unlock': 2,
#          'one': 2,
#          'require': 2,
#          'scientist': 2,
#          'amp': 2,
#          'asset': 2,
#          'cause': 2,
#          'headache': 2,
#          'hardcover': 2,
#          'federal': 2,
#          'aim': 2,
#          'reprocessing': 2,
#          'fda': 2,
#          'enhance': 2,
#          'demystifying': 2,
#          'measured': 2,
#          'matter': 2,
#          'rt': 2,
#          'variability': 2,
#          'identified': 2,
#          'lambda': 2,
#          'consortium': 2,
#          'oncology': 2,
#          'reimbursement': 2,
#          'philosophy': 2,
#          ...})

# %%
# 임시 딕션너리 만들기. 
word_count = dict()

# 상위 50개 정도만 추출 해보기. 
for tag, counts in count.most_common(50):
  if(len(str(tag)) >1):
    word_count[tag] = counts
    print(f"tag : {tag}, counts : {counts}")

word_count
# Out:
# tag : data, counts : 1226
# tag : big, counts : 1103
# tag : analytics, counts : 133
# tag : based, counts : 117
# tag : analysis, counts : 113
# tag : system, counts : 68
# tag : driven, counts : 68
# tag : using, counts : 68
# tag : approach, counts : 66
# tag : learning, counts : 56
# tag : model, counts : 55
# tag : issue, counts : 53
# tag : application, counts : 46
# tag : special, counts : 42
# tag : management, counts : 41
# tag : algorithm, counts : 40
# tag : framework, counts : 39
# tag : call, counts : 36
# tag : science, counts : 36
# tag : platform, counts : 36
# tag : paper, counts : 35
# tag : challenge, counts : 34
# tag : network, counts : 34
# tag : new, counts : 33
# tag : cloud, counts : 33
# tag : performance, counts : 30
# tag : era, counts : 30
# tag : health, counts : 30
# tag : machine, counts : 30
# tag : research, counts : 29
# tag : review, counts : 29
# tag : mining, counts : 29
# tag : processing, counts : 28
# tag : earth, counts : 28
# tag : computing, counts : 26
# tag : real, counts : 26
# tag : perspective, counts : 25
# tag : optimization, counts : 25
# tag : world, counts : 25
# tag : method, counts : 24
# tag : study, counts : 24
# tag : technology, counts : 24
# tag : business, counts : 24
# tag : service, counts : 24
# tag : opportunity, counts : 23
# tag : distributed, counts : 23
# tag : survey, counts : 22
# tag : efficient, counts : 22
# tag : use, counts : 21
# tag : medical, counts : 21
# {'data': 1226,
#  'big': 1103,
#  'analytics': 133,
#  'based': 117,
#  'analysis': 113,
#  'system': 68,
#  'driven': 68,
#  'using': 68,
#  'approach': 66,
#  'learning': 56,
#  'model': 55,
#  'issue': 53,
#  'application': 46,
#  'special': 42,
#  'management': 41,
#  'algorithm': 40,
#  'framework': 39,
#  'call': 36,
#  'science': 36,
#  'platform': 36,
#  'paper': 35,
#  'challenge': 34,
#  'network': 34,
#  'new': 33,
#  'cloud': 33,
#  'performance': 30,
#  'era': 30,
#  'health': 30,
#  'machine': 30,
#  'research': 29,
#  'review': 29,
#  'mining': 29,
#  'processing': 28,
#  'earth': 28,
#  'computing': 26,
#  'real': 26,
#  'perspective': 25,
#  'optimization': 25,
#  'world': 25,
#  'method': 24,
#  'study': 24,
#  'technology': 24,
#  'business': 24,
#  'service': 24,
#  'opportunity': 23,
#  'distributed': 23,
#  'survey': 22,
#  'efficient': 22,
#  'use': 21,
#  'medical': 21}

# %%
# 추출된 상위 50개 단어 시각화하기. 
# 막대그래프 
# word_count : 상위 50개 단어 추출한 , 딕션너리 = Map 비슷 ,key : value 
# 기본이 : 오름 차순, reverse, 내림 차순이라고 보면 됨. 
sorted_Keys = sorted(word_count, key = word_count.get, reverse=True)

# values 추출, 내림 차순 
sorted_Values= sorted(word_count.values(), reverse=True)

# 시각화 
# x축 : range(len(word_count))
# Y축 : sorted_Values
plt.bar(range(len(word_count)),sorted_Values, align='center')
# 눈금 옵션 조정. x축 라벨 붙이기 작업. rotation 세로 방향으로 기울이기. 
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = "vertical")

plt.show()

# %%
# 기존 데이터 프레임에 새로운 컬럼(doc_count) 추가, 임의로 0으로 값 넣기. 
all_files_data_concat["doc_count"] = 0

#  출판일 기준으로 그룹화해서, count 집계 표기 하기.
# as_index=False 옵션을 사용하면 그룹화된 결과의 "출판일"이 인덱스가 아닌 일반 열로 유지됩니다.
summary_date = all_files_data_concat.groupby("출판일", as_index=False)["doc_count"].count()
summary_date
# Out:
#      출판일  doc_count
# 0   2003          1
# 1   2011          2
# 2   2012         12
# 3   2013         41
# 4   2014         82
# 5   2015         69
# 6   2016         75
# 7   2017         94
# 8   2018         88
# 9   2019         64
# 10  2020         96
# 11  2021         74
# 12  2022         62
# 13  2023         28
# 14  2024         11
# 15  2025          1
# 16     -          2
# 17  2004          1
# 18  2012          2
# 19  2013          4
# 20  2014          9
# 21  2015          9
# 22  2016         22
# 23  2017         23
# 24  2018         20
# 25  2019         23
# 26  2020         27
# 27  2021         27
# 28  2022         16
# 29  2023         15

# %%
# 꺽은선 그래프 
# 가로 세로 비율
plt.figure(figsize=(12,5))
plt.xlabel("year")
plt.ylabel("doc_count")
plt.grid(True)
# x축 : range(len(summary_date))
# y축 : summary_date["doc_count"]
plt.plot(range(len(summary_date)), summary_date["doc_count"] )
# x축 라벨링 옵션 
plt.xticks(range(len(summary_date)), [text for text in summary_date["출판일"]])
plt.show()

# %%
3# 이미지 추가 수정1
from PIL import Image
import numpy as np

# 워드 클라우드 공식 문서 , 다양한 이미지 위에 처리하기.
# https://amueller.github.io/word_cloud/index.html

# 워드 클라우드 시각화
# STOPWORDS는 WordCloud 라이브러리에서 제공하는 기본 불용어 집합입니다.
# 이 코드는 STOPWORDS를 집합(set)으로 변환하여,
# 워드 클라우드 생성 시 불필요한 단어(예: "the", "and" 등)를 제거하는 데 사용합니다.
stopwords = set(STOPWORDS)

# 이미지 추가 수정2
alice_mask = np.array(Image.open("convert_result3.png"))
# stopwords=stopwords:
# 위에서 정의한 불용어 집합을 사용하여, 워드 클라우드에 포함하지 않을 단어들을 지정합니다.
# wc = WordCloud(background_color="ivory", stopwords=stopwords, width=800, height=600)

# 이미지 추가 수정3
wc = WordCloud(background_color="white", max_words=1000, mask=alice_mask)
# word_count는 단어와 해당 단어의 빈도수를 담은 사전(dictionary)입니다.
# 이 메서드는 word_count에 저장된 단어들의 빈도 정보를 바탕으로 워드 클라우드를 생성하고, 그 결과를 cloud에 저장합니다.
cloud = wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis("off")
plt.show()
# data': 1235,
#  'big': 1113,
#  'analytics': 110,
#  'based': 102,
#  'analysis': 93,
#  'driven': 70,
#  'system': 64,
#  'using': 57,
